# %%
import pandas

# %%
data = pandas.read_csv(u'C:\\Users\\Dmi\\Desktop\\MatLab\\Coursera\\Введение в машинное обучение\\Неделя 1\\titanic.csv', 
                       index_col='PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
print data['Sex'].value_counts()
print sum(data['Survived']) 
print len(data['Survived']) 
print (round(sum(data['Survived'])*1./len(data['Survived'])*100, 2))
print (round(data['Pclass'].value_counts()[1]*1. / len(data['Pclass'])*100 ,2))
print round(data['Age'].mean(), 2)
print data['Age'].median()
print round(data.corr()['SibSp']['Parch'], 2)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# 342
# 891
# 38.38
# 24.24
# 29.7
# 28.0
# 0.41

# %%
# print data.loc[data['Sex'] == 'female']['Name']
df = pandas.DataFrame(data.loc[data['Sex'] == 'female']['Name'].str.split('.',1).tolist())
print df[1].value_counts()
# Out:
#  Mary                                                       6
#  Bertha                                                     4
#  Anna                                                       3
#  Anna Sofia                                                 3
#  Elizabeth                                                  2
#  Marija                                                     2
#  Ellen "Nellie"                                             2
#  Kate                                                       2
#  Alice                                                      2
#  Hanora "Nora"                                              2
#  Katherine "Katie"                                          2
#  John Jacob (Madeleine Talmadge Force)                      1
#  Ernest Courtenay (Lilian Hughes)                           1
#  Fatima                                                     1
#  Rosalie                                                    1
# ...
