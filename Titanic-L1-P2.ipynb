# %%
import pandas
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
data = pandas.read_csv(u'C:\\Users\\Dmi\\Desktop\\MatLab\\Coursera\\Введение в машинное обучение\\Неделя 1\\titanic.csv', 
                       index_col='PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df = data[['Pclass','Fare','Age']]
survived = data['Survived']
print df, survived
# Out:
#              Pclass      Fare  Age
# PassengerId
# 1                 3    7.2500   22
# 2                 1   71.2833   38
# 3                 3    7.9250   26
# 4                 1   53.1000   35
# 5                 3    8.0500   35
# 6                 3    8.4583  NaN
# 7                 1   51.8625   54
# 8                 3   21.0750    2
# 9                 3   11.1333   27
# 10                2   30.0708   14
# 11                3   16.7000    4
# 12                1   26.5500   58
# 13                3    8.0500   20
# 14                3   31.2750   39
# 15                3    7.8542   14
# 16                2   16.0000   55
# 17                3   29.1250    2
# 18                2   13.0000  NaN
# 19                3   18.0000   31
# 20                3    7.2250  NaN
# 21                2   26.0000   35
# 22                2   13.0000   34
# 23                3    8.0292   15
# 24                1   35.5000   28
# 25                3   21.0750    8
# 26                3   31.3875   38
# 27                3    7.2250  NaN
# 28                1  263.0000   19
# 29                3    7.8792  NaN
# 30                3    7.8958  NaN
# ...             ...       ...  ...
# 862               2   11.5000   21
# 863               1   25.9292   48
# 864               3   69.5500  NaN
# 865               2   13.0000   24
# 866               2   13.0000   42
# 867               2   13.8583   27
# 868               1   50.4958   31
# 869               3    9.5000  NaN
# 870               3   11.1333    4
# 871               3    7.8958   26
# 872               1   52.5542   47
# 873               1    5.0000   33
# 874               3    9.0000   47
# 875               2   24.0000   28
# 876               3    7.2250   15
# 877               3    9.8458   20
# 878               3    7.8958   19
# 879               3    7.8958  NaN
# 880               1   83.1583   56
# 881               2   26.0000   25
# 882               3    7.8958   33
# 883               3   10.5167   22
# 884               2   10.5000   28
# 885               3    7.0500   25
# 886               3   29.1250   39
# 887               2   13.0000   27
# 888               1   30.0000   19
# 889               3   23.4500  NaN
# 890               1   30.0000   26
# 891               3    7.7500   32
#
# [891 rows x 3 columns] PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      1
# 10     1
# 11     1
# 12     1
# 13     0
# 14     0
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     1
# 21     0
# 22     1
# 23     1
# 24     1
# 25     0
# 26     1
# 27     0
# 28     0
# 29     1
# 30     0
#       ..
# 862    0
# 863    1
# 864    0
# 865    0
# 866    1
# 867    1
# 868    0
# 869    0
# 870    1
# 871    0
# 872    1
# 873    0
# 874    0
# 875    1
# 876    1
# 877    0
# 878    0
# 879    0
# 880    1
# 881    1
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, dtype: int64

# %%
X = np.array(df)
y = np.array(survived)
df['Sex'] = pandas.get_dummies(data['Sex'])['male']
indices = np.any(np.isnan(df), axis=1)
X_clear = X[~indices]
y_clear = y[~indices]
print X_clear[:10]
print
# Out:
# [[  3.       7.25    22.       1.    ]
#  [  1.      71.2833  38.       0.    ]
#  [  3.       7.925   26.       0.    ]
#  [  1.      53.1     35.       0.    ]
#  [  3.       8.05    35.       1.    ]
#  [  1.      51.8625  54.       1.    ]
#  [  3.      21.075    2.       1.    ]
#  [  3.      11.1333  27.       0.    ]
#  [  2.      30.0708  14.       0.    ]
#  [  3.      16.7      4.       0.    ]]

# %%
clf = DecisionTreeClassifier(random_state=241)
clf.fit(X_clear, y_clear)
importances = clf.feature_importances_
print importances
print df.columns.values
# Out:
# [ 0.14000522  0.30423785  0.25524472  0.30051221]
# ['Pclass' 'Fare' 'Age' 'Sex']

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn import tree
import pydot
dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data)  
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-cb2879572ef6> in <module>()
#       5 dot_data = StringIO()
#       6 tree.export_graphviz(clf, out_file=dot_data)
# ----> 7 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#       8 Image(graph.create_png())
#
# C:\Python27\lib\site-packages\pydot.pyc in graph_from_dot_data(data)
#     197         return s
#     198
# --> 199     if needs_quotes(s):
#     200         replace = {'"'  : r'\"',
#     201                    "\n" : r'\n',
#
# NameError: global name 'dot_parser' is not defined
